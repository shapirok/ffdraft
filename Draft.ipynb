# %%
import DraftRunner as dr
import Draft as d
myDraft = d.Draft()

# %%
myDraft.utility_adjusted_cheatsheet()
# Out:
#                     First              Last Team Position  ESPNRank  FPRank  \
# Index
# J HOW RB CHI       Jordan            Howard  CHI       RB        36    23.0
# T HIL WR IND         T.Y.            Hilton  IND       WR        24    24.0
# J MIX RB CIN          Joe             Mixon  CIN       RB        38    25.0
# R GRO TE NE           Rob        Gronkowski   NE       TE        20    20.0
# J MCK RB SF        Jerick          McKinnon   SF       RB        37    26.0
# D BAL WR SEA         Doug           Baldwin  SEA       WR        32    27.0
# A THI WR MIN         Adam           Thielen  MIN       WR        25    28.0
# S DIG WR MIN       Stefon             Diggs  MIN       WR        26    29.0
# T HIL WR KC        Tyreek              Hill   KC       WR        27    30.0
# A COL RB BAL         Alex           Collins  BAL       RB        45    32.0
# A COO WR OAK        Amari            Cooper  OAK       WR        33    34.0
# A ROB WR CHI        Allen          Robinson  CHI       WR        31    35.0
# J AJA RB PHI          Jay             Ajayi  PHI       RB        46    36.0
# L FIT WR ARI        Larry        Fitzgerald  ARI       WR        28    37.0
# T KEL TE KC        Travis             Kelce   KC       TE        29    33.0
# D HEN RB TEN      Derrick             Henry  TEN       RB        44    38.0
# M JON WR DET       Marvin             Jones  DET       WR        35    41.0
# K DRA RB MIA       Kenyan             Drake  MIA       RB        43    42.0
# J SMI WR PIT         JuJu    Smith-Schuster  PIT       WR        52    43.0
# D THO WR DEN    Demaryius            Thomas  DEN       WR        39    44.0
# Z ERT TE PHI         Zach              Ertz  PHI       TE        30    39.0
# G TAT WR DET       Golden              Tate  DET       WR        42    45.0
# A ROD QB GB         Aaron           Rodgers   GB       QB        56    40.0
# L MIL RB HOU        Lamar            Miller  HOU       RB        50    46.0
# A JEF WR PHI       Alshon           Jeffery  PHI       WR        40    47.0
# B COO WR LAR      Brandin             Cooks  LAR       WR        41    48.0
# J GOR WR CLE         Josh            Gordon  CLE       WR        34    49.0
# R FRE RB DEN        Royce           Freeman  DEN       RB        47    50.0
# J LAN WR CLE       Jarvis            Landry  CLE       WR        51    51.0
# M ING RB NO          Mark            Ingram   NO       RB        58    52.0
# ...                   ...               ...  ...      ...       ...     ...
# M VAL WR GB       Marquez  Valdes-Scantling   GB       WR       260     NaN
# E ST. WR GB   Equanimeous               St.   GB       WR       261     NaN
# A HUM WR TB          Adam         Humphries   TB       WR       263     NaN
# J WIL RB SF           Joe          Williams   SF       RB       264     NaN
# C SIM RB TB       Charles              Sims   TB       RB       265     NaN
# S DAR QB NYJ          Sam           Darnold  NYJ       QB       269     NaN
# K COU WR HOU         Keke            Coutee  HOU       WR       271     NaN
# D CHA WR JAC         D.J.             Chark  JAC       WR       272     NaN
# R SWI WR OAK         Ryan           Switzer  OAK       WR       273     NaN
# D HAM WR DEN      DaeSean          Hamilton  DEN       WR       274     NaN
# T SMI WR NO      Tre'Quan             Smith   NO       WR       275     NaN
# D HEN RB DEN    De'Angelo         Henderson  DEN       RB       276     NaN
# T WES RB NO      Terrance              West   NO       RB       278     NaN
# B SCO RB NO        Boston             Scott   NO       RB       279     NaN
# J SAM RB PIT       Jaylen           Samuels  PIT       RB       280     NaN
# D WIL RB KC        Damien          Williams   KC       RB       281     NaN
# T LOG RB ARI         T.J.             Logan  ARI       RB       282     NaN
# J JAC RB LAC       Justin           Jackson  LAC       RB       283     NaN
# C SAM WR CAR       Curtis            Samuel  CAR       WR       284     NaN
# DEF GB                NaN               NaN   GB      DEF       285     NaN
# J LAM K JAC          Josh             Lambo  JAC        K       287     NaN
# D HOP K WAS        Dustin           Hopkins  WAS        K       288     NaN
# V DAV TE WAS       Vernon             Davis  WAS       TE       290     NaN
# T KRO TE CIN        Tyler             Kroft  CIN       TE       291     NaN
# B JAR TE DAL        Blake            Jarwin  DAL       TE       292     NaN
# G EVE TE LAR       Gerald           Everett  LAR       TE       293     NaN
# T GAB WR CHI       Taylor           Gabriel  CHI       WR       294     NaN
# A MCC QB BUF           AJ          McCarron  BUF       QB       296     NaN
# DEF CIN               NaN               NaN  CIN      DEF       297     NaN
# DEF DET               NaN               NaN  DET      DEF       298     NaN
#
#               Upside            Injury Status  \
# Index
# J HOW RB CHI    -3.0                      NaN
# T HIL WR IND    -3.0                      NaN
# J MIX RB CIN    -4.0                      NaN
# R GRO TE NE     -4.0                      NaN
# J MCK RB SF     -3.0  Questionable for Week 1
# D BAL WR SEA    -4.0         Ready for Week 1
# A THI WR MIN    -4.0                      NaN
# S DIG WR MIN    -3.0                      NaN
# T HIL WR KC     -2.0                      NaN
# A COL RB BAL    -3.0                      NaN
# A COO WR OAK    -1.0                      NaN
# A ROB WR CHI    -3.0                      NaN
# J AJA RB PHI     4.0                      NaN
# L FIT WR ARI    -3.0                      NaN
# T KEL TE KC      2.0                      NaN
# D HEN RB TEN    -2.0                      NaN
# M JON WR DET    -0.0                      NaN
# K DRA RB MIA     5.0                      NaN
# J SMI WR PIT    -3.0                      NaN
# D THO WR DEN    -0.0                      NaN
# Z ERT TE PHI    -1.0                      NaN
# G TAT WR DET    -4.0                      NaN
# A ROD QB GB     64.0                      NaN
# L MIL RB HOU    -3.0                      NaN
# A JEF WR PHI     1.0  Questionable for Week 1
# B COO WR LAR    -1.0                      NaN
# J GOR WR CLE    -1.0                      NaN
# R FRE RB DEN    14.0                      NaN
# J LAN WR CLE    -2.0                      NaN
# M ING RB NO      4.0            Return Week 5
# ...              ...                      ...
# M VAL WR GB      NaN                      NaN
# E ST. WR GB      NaN                      NaN
# A HUM WR TB      NaN                      NaN
# J WIL RB SF      NaN         Out indefinitely
# C SIM RB TB      NaN                   Week 1
# S DAR QB NYJ     NaN                      NaN
# K COU WR HOU     NaN                      NaN
# D CHA WR JAC     NaN                      NaN
# R SWI WR OAK     NaN                      NaN
# D HAM WR DEN     NaN                      NaN
# T SMI WR NO      NaN                      NaN
# D HEN RB DEN     NaN                      NaN
# T WES RB NO      NaN                      NaN
# B SCO RB NO      NaN                      NaN
# J SAM RB PIT     NaN                      NaN
# D WIL RB KC      NaN                      NaN
# T LOG RB ARI     NaN                      NaN
# J JAC RB LAC     NaN                      NaN
# C SAM WR CAR     NaN                      NaN
# DEF GB           NaN                      NaN
# J LAM K JAC      NaN                      NaN
# D HOP K WAS      NaN                      NaN
# V DAV TE WAS     NaN                      NaN
# T KRO TE CIN     NaN                      NaN
# B JAR TE DAL     NaN                      NaN
# G EVE TE LAR     NaN                      NaN
# T GAB WR CHI     NaN               Day to day
# A MCC QB BUF     NaN         Status uncertain
# DEF CIN          NaN                      NaN
# DEF DET          NaN                      NaN
#
#                                                                                        Blurb  \
# Index
# J HOW RB CHI             Pass-game limitations but big TD upside in likely-improved offense.
# T HIL WR IND     Led NFL in receiving yards in ’16. Keeps rising as Luck proves his health.
# J MIX RB CIN          After sluggish rookie campaign, has dropped 20 lbs since 2017 spring.
# R GRO TE NE                   Monster TD & volume upside without Cooks & Edelman Weeks 1-4.
# J MCK RB SF       Sidelined by calf strain. Alfred Morris is legitimate threat for carries.
# D BAL WR SEA            WR9 pre-knee injury. Drafting already-injured players always scary.
# A THI WR MIN            Elite route runner has major room for TD growth after 4-score 2017.
# S DIG WR MIN            High-end WR1 whenever not battling groin injuries last two seasons.
# T HIL WR KC              Each of TyFreak’s last 13 touchdowns have come from 30+ yards out.
# A COL RB BAL           Avg’d 19.2 touches/game from Week 8 on. Gets both starting OGs back.
# A COO WR OAK                Gruden says “main vein” of pass game, comp’d to Sterling Sharpe.
# A ROB WR CHI            Fade at ADP. Off ACL, changing teams, hasn’t played well since 2015.
# J AJA RB PHI     Avg’d 15.7 touches over final 6 games. Eagles missing 190 carries from ‘17.
# L FIT WR ARI            100+ catches 3 straight years. Has minimal competition for targets.
# T KEL TE KC   Kelce’s targets per game have risen 4 straight years (5.4 > 6.4 > 7.3 > 8.1).
# D HEN RB TEN             Monster touchdown upside vs. soft schedule with improved coaching.
# M JON WR DET      Led NFL in yds/catch (18.0) in ‘17. Eric Ebron’s exit frees up 86 targets.
# K DRA RB MIA          Expected to share time with Frank Gore despite white-hot 2017 finish.
# J SMI WR PIT                   Safe WR2 with league-winner upside following Martavis ouster.
# D THO WR DEN                Coming off 6-year lows in catch rate, yds/catch. 31 in December.
# Z ERT TE PHI       Including playoffs, went 92/1,016/9 in 17 gms. Alshon absence would help.
# G TAT WR DET         Elite tackle breaker has 90+ catches 4 straight seasons. Contract year.
# A ROD QB GB                                                           40 TDs last 16 games.
# L MIL RB HOU            1,200+ total yards 4 straight years. D’Onta Foreman headed for PUP.
# A JEF WR PHI            Long recovery from rotator cuff surgery has Week 1 status in doubt.
# B COO WR LAR        Volume likely to take hit in L.A. but should still mix in spiked weeks.
# J GOR WR CLE          Classic boom-bust pick. Browns seem confident Gordon will play in ’18.
# R FRE RB DEN             DEN likely lead RB will lose passing-down snaps to Devontae Booker.
# J LAN WR CLE          Set to vacuum targets again as Browns WRs around him drop like flies.
# M ING RB NO          Suspended Weeks 1-4 (PEDs). Role all but certain to lessen upon return.
# ...                                                                                      ...
# M VAL WR GB                                                                              NaN
# E ST. WR GB                                                                              NaN
# A HUM WR TB                                                                              NaN
# J WIL RB SF                                                                              NaN
# C SIM RB TB                                                                              NaN
# S DAR QB NYJ                                                                             NaN
# K COU WR HOU                                                                             NaN
# D CHA WR JAC                                                                             NaN
# R SWI WR OAK                                                                             NaN
# D HAM WR DEN                                                                             NaN
# T SMI WR NO                                                                              NaN
# D HEN RB DEN                                                                             NaN
# T WES RB NO                                                                              NaN
# B SCO RB NO                                                                              NaN
# J SAM RB PIT                                                                             NaN
# D WIL RB KC                                                                              NaN
# T LOG RB ARI                                                                             NaN
# J JAC RB LAC                                                                             NaN
# C SAM WR CAR                                                                             NaN
# DEF GB                                                                                   NaN
# J LAM K JAC                                                                              NaN
# D HOP K WAS                                                                              NaN
# V DAV TE WAS                                                                             NaN
# T KRO TE CIN                                                                             NaN
# B JAR TE DAL                                                                             NaN
# G EVE TE LAR                                                                             NaN
# T GAB WR CHI                                                                             NaN
# A MCC QB BUF                                                                             NaN
# DEF CIN                                                                                  NaN
# DEF DET                                                                                  NaN
#
#               UtilRank
# Index
# J HOW RB CHI       1.0
# T HIL WR IND       2.0
# J MIX RB CIN       3.0
# R GRO TE NE        4.0
# J MCK RB SF        5.0
# D BAL WR SEA       6.0
# A THI WR MIN       7.0
# S DIG WR MIN       8.0
# T HIL WR KC        9.0
# A COL RB BAL      10.0
# A COO WR OAK      11.0
# A ROB WR CHI      12.0
# J AJA RB PHI      13.0
# L FIT WR ARI      14.0
# T KEL TE KC       15.0
# D HEN RB TEN      16.0
# M JON WR DET      17.0
# K DRA RB MIA      18.0
# J SMI WR PIT      19.0
# D THO WR DEN      20.0
# Z ERT TE PHI      21.0
# G TAT WR DET      22.0
# A ROD QB GB       23.0
# L MIL RB HOU      24.0
# A JEF WR PHI      25.0
# B COO WR LAR      26.0
# J GOR WR CLE      27.0
# R FRE RB DEN      28.0
# J LAN WR CLE      29.0
# M ING RB NO       30.0
# ...                ...
# M VAL WR GB      249.0
# E ST. WR GB      250.0
# A HUM WR TB      251.0
# J WIL RB SF      252.0
# C SIM RB TB      253.0
# S DAR QB NYJ     254.0
# K COU WR HOU     255.0
# D CHA WR JAC     256.0
# R SWI WR OAK     257.0
# D HAM WR DEN     258.0
# T SMI WR NO      259.0
# D HEN RB DEN     260.0
# T WES RB NO      261.0
# B SCO RB NO      262.0
# J SAM RB PIT     263.0
# D WIL RB KC      264.0
# T LOG RB ARI     265.0
# J JAC RB LAC     266.0
# C SAM WR CAR     267.0
# DEF GB           268.0
# J LAM K JAC      269.0
# D HOP K WAS      270.0
# V DAV TE WAS     271.0
# T KRO TE CIN     272.0
# B JAR TE DAL     273.0
# G EVE TE LAR     274.0
# T GAB WR CHI     275.0
# A MCC QB BUF     276.0
# DEF CIN          277.0
# DEF DET          278.0
#
# [278 rows x 10 columns]

# %%
dr.ConsoleDraftRunner(myDraft)
# Out:
# Invalid command
# Input (C=CheatSheet,D=Draft,
# 	U=Undo,Q=Quit,P=Picks,R=Roster,I=Info,N=News): q

# %%
myDraft.auto_draft(23,'ESPNRank')
# Out:
#         First       Last Position Team  Pick  Roster
# 0     Le'Veon       Bell       RB  PIT   1.0     1.0
# 1        Todd     Gurley       RB  LAR   2.0     2.0
# 2       David    Johnson       RB  ARI   3.0     3.0
# 3     Ezekiel    Elliott       RB  DAL   4.0     4.0
# 4     Antonio      Brown       WR  PIT   5.0     5.0
# 5      Saquon    Barkley       RB  NYG   6.0     6.0
# 6       Alvin     Kamara       RB   NO   7.0     7.0
# 7       Julio      Jones       WR  ATL   8.0     8.0
# 8       Odell    Beckham       WR  NYG   9.0     9.0
# 9     DeAndre    Hopkins       WR  HOU  10.0    10.0
# 10     Kareem       Hunt       RB   KC  11.0    11.0
# 11    Leonard  Fournette       RB  JAC  12.0    12.0
# 12     Dalvin       Cook       RB  MIN  13.0    12.0
# 13     Melvin     Gordon       RB  LAC  14.0    11.0
# 14     Keenan      Allen       WR  LAC  15.0    10.0
# 15    Michael     Thomas       WR   NO  16.0     9.0
# 16    Devonta    Freeman       RB  ATL  17.0     8.0
# 17       A.J.      Green       WR  CIN  18.0     7.0
# 18  Christian  McCaffrey       RB  CAR  19.0     6.0
# 19    Davante      Adams       WR   GB  20.0     5.0
# 20       Mike      Evans       WR   TB  21.0     4.0
# 21     LeSean      McCoy       RB  BUF  22.0     3.0
