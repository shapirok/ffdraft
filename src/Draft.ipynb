# %%
import DraftRunner as dr
import Draft as d
import threading
myDraft = d.Draft()

# %%
dr.ConsoleDraftRunner(myDraft, runContinuous=True)
# Out:
# Quit

# %%
myDraft.get_picks()
# Out:
#      First  Last Position Team  Pick  Roster
# 0  Le'Veon  Bell       RB  PIT   1.0     1.0

# %%
myDraft.utility_adjusted_cheatsheet()
# Out:
#         First       Last Team Position  ESPNRank  FPRank  Upside  \
# 0        Todd     Gurley  LAR       RB         2     1.0    -3.0
# 1     Ezekiel    Elliott  DAL       RB         4     3.0    -3.0
# 2       David    Johnson  ARI       RB         3     4.0    -3.0
# 3     Antonio      Brown  PIT       WR         5     5.0    -3.0
# 4     DeAndre    Hopkins  HOU       WR        10     6.0    -3.0
# 5       Alvin     Kamara   NO       RB         7     7.0    -1.0
# 6      Saquon    Barkley  NYG       RB         6     8.0    -3.0
# 7       Odell    Beckham  NYG       WR         9     9.0    -3.0
# 8      Melvin     Gordon  LAC       RB        14    10.0    -2.0
# 9       Julio      Jones  ATL       WR         8    11.0    -3.0
# 10    Leonard  Fournette  JAC       RB        12    12.0    -3.0
# 11     Kareem       Hunt   KC       RB        11    13.0    -3.0
# 12    Michael     Thomas   NO       WR        16    14.0    -4.0
# 13     Dalvin       Cook  MIN       RB        13    15.0    -1.0
# 14     Keenan      Allen  LAC       WR        15    16.0    -3.0
# 15       A.J.      Green  CIN       WR        18    17.0    -4.0
# 16    Davante      Adams   GB       WR        21    18.0    -3.0
# 17    Devonta    Freeman  ATL       RB        17    19.0    -3.0
# 18       Mike      Evans   TB       WR        22    21.0    -3.0
# 19  Christian  McCaffrey  CAR       RB        19    22.0    -2.0
#
#    Injury Status  \
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6     Day to day
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
#
#                                                                           Blurb  \
# 0           Emerged as NFL’s premier 3-down back in first year with Sean McVay.
# 1          Elliott has averaged 24.9 touches with 25 TDs through 25 NFL games.
# 2   I lean DJ over Zeke in full PPR but take Elliott in non- & 0.5-PPR drafts.
# 3     150+ targets 5 straight years. Has battled quad injury in training camp.
# 4             Last year’s overall WR1 with Watson. Also WR1 with Savage/Yates.
# 5   Last year’s RB4 on only 7.5 carries/game. Workload set to spike in year 2.
# 6         Cross between David Johnson-LeSean McCoy. Should rarely leave field.
# 7         Has finished WR5 or better in fantasy points/game in 4-of-4 seasons.
# 8          Passing-game usage has risen every year. Now has best OL of career.
# 9    1,400+ receiving yards 4 straight years. Should experience +TD regression.
# 10          Has shed 17 lbs since rookie offseason. Drew 381 touches in year 1.
# 11   Led NFL in rushing yards, yards after contact & broken tackles as rookie.
# 12         Plus-sized technician has room for big TD growth after 5-score ’17.
# 13       Back from ACL tear. OL concerns. May lose GL work to Latavius Murray.
# 14         Should dominate Chargers RZ looks with Hunter Henry out of picture.
# 15      Turned 30 in July. Top-12 fantasy WR in points/game in 7-of-7 seasons.
# 16       Leads NFL in receiving TDs (22) and RZ targets (46) last two seasons.
# 17         High-floor, job-secure lead RB in Falcons offense likely to rebound.
# 18      Went 5/92/0, 6/78/0, 3/95/1 in 3 games with Ryan Fitzpatrick last year.
# 19               Swept 1st-team snaps & executed GL carry in preseason opener.
#
#     UtilRank
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
# 5        6.0
# 6        7.0
# 7        8.0
# 8        9.0
# 9       10.0
# 10      11.0
# 11      12.0
# 12      13.0
# 13      14.0
# 14      15.0
# 15      16.0
# 16      17.0
# 17      18.0
# 18      19.0
# 19      20.0
